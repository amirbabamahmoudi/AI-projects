# %%
#dataset_link:https://www.kaggle.com/bahramjannesarr/goodreads-book-datasets-10m
import pandas as pd
good_reads = pd.read_csv('book1-100k.csv' , low_memory=False)
good_reads = good_reads[good_reads['Language'] == 'eng']

# %%
#good_reads.head(5)
good_reads2 = good_reads[['Name' , 'RatingDistTotal' , 'Publisher' , 'Authors' , 'Rating' ]]
good_reads2.head(5)
# Out:
#                                                 Name RatingDistTotal  \
# 0  Harry Potter and the Half-Blood Prince (Harry ...   total:2298124
# 1  Harry Potter and the Order of the Phoenix (Har...   total:2358637
# 2  Harry Potter and the Sorcerer's Stone (Harry P...   total:6587388
# 3  Harry Potter and the Chamber of Secrets (Harry...   total:2560657
# 4  Harry Potter and the Prisoner of Azkaban (Harr...   total:2610317
#
#          Publisher       Authors  Rating
# 0  Scholastic Inc.  J.K. Rowling    4.57
# 1  Scholastic Inc.  J.K. Rowling    4.50
# 2   Scholastic Inc  J.K. Rowling    4.47
# 3       Scholastic  J.K. Rowling    4.42
# 4  Scholastic Inc.  J.K. Rowling    4.57

# %%
good_reads2['RatingDistTotal']
# Out:
# 0        total:2298124
# 1        total:2358637
# 2        total:6587388
# 3        total:2560657
# 4        total:2610317
#              ...
# 58260        total:265
# 58262      total:11162
# 58265       total:3666
# 58280         total:25
# 58281         total:51
# Name: RatingDistTotal, Length: 15988, dtype: object

# %%
total_vots["total_vote"] = good_reads2.RatingDistTotal.str.extract('(\d+)')
good_reads2['total_votes'] = total_vots['total_vote'] 
good_reads2.head(5)
# Out:
# <ipython-input-76-9c0f8e267ac4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   good_reads2['total_votes'] = total_vots['total_vote']
#                                                 Name RatingDistTotal  \
# 0  Harry Potter and the Half-Blood Prince (Harry ...   total:2298124
# 1  Harry Potter and the Order of the Phoenix (Har...   total:2358637
# 2  Harry Potter and the Sorcerer's Stone (Harry P...   total:6587388
# 3  Harry Potter and the Chamber of Secrets (Harry...   total:2560657
# 4  Harry Potter and the Prisoner of Azkaban (Harr...   total:2610317
#
#          Publisher       Authors  Rating total_votes
# 0  Scholastic Inc.  J.K. Rowling    4.57     2298124
# 1  Scholastic Inc.  J.K. Rowling    4.50     2358637
# ...

# %%
good_reads2['total_votes'] = total_rating['total_rating']
# Out:
# <ipython-input-43-04fe1b013bd5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   good_reads2['total_votes'] = total_rating['total_rating']

# %%
good_reads2.drop('RatingDistTotal', axis=1 , inplace=True)
# Out:
# /home/amir/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
good_reads2
# Out:
#                                                     Name  \
# 0      Harry Potter and the Half-Blood Prince (Harry ...
# 1      Harry Potter and the Order of the Phoenix (Har...
# 2      Harry Potter and the Sorcerer's Stone (Harry P...
# 3      Harry Potter and the Chamber of Secrets (Harry...
# 4      Harry Potter and the Prisoner of Azkaban (Harr...
# ...                                                  ...
# 58260  Thomas Paine and the Promise of America (Oxfor...
# 58262                    Common Sense and Other Writings
# 58265               Faith of My Fathers: A Family Memoir
# 58280                  Science Fiction: The Best of 2001
# 58281                        Nebula Awards Showcase 2001
#
#                        Publisher            Authors  Rating total_votes
# 0                Scholastic Inc.       J.K. Rowling    4.57     2298124
# 1                Scholastic Inc.       J.K. Rowling    4.50     2358637
# ...

# %%
good_reads2['total_votes'] = good_reads2['total_votes'].astype(float)
C = good_reads2['Rating'].mean()
m = good_reads2['total_votes'].quantile(0.90)
q_books = good_reads2.copy().loc[good_reads2['total_votes'] >= m]
m
# Out:
# <ipython-input-89-017ec751d696>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   good_reads2['total_votes'] = good_reads2['total_votes'].astype(float)
# 42348.60000000002

# %%
def weighted_rating(x, m=m, C=C):
    v = x['total_votes']
    R = x['Rating']
    # Calculation based on the IMDB formula
    return (v/(v+m) * R) + (m/(m+v) * C)
q_books['score'] = q_books.apply(weighted_rating, axis=1)
q_books = q_books.sort_values('score', ascending=False)
q_books.head(5)
q_books.drop('RatingDistTotal' , axis = 1 , inplace = True)
q_books.drop('Publisher' , axis = 1 , inplace = True)
q_books.head(20)
# Out:
#                                                     Name         Authors  \
# 41331  Harry Potter and the Deathly Hallows (Harry Po...    J.K. Rowling
# 4      Harry Potter and the Prisoner of Azkaban (Harr...    J.K. Rowling
# 54174  Harry Potter and the Half-Blood Prince (Harry ...    J.K. Rowling
# 40728  Harry Potter and the Half-blood Prince (Harry ...    J.K. Rowling
# 0      Harry Potter and the Half-Blood Prince (Harry ...    J.K. Rowling
# 5      Harry Potter and the Goblet of Fire (Harry Pot...    J.K. Rowling
# 9245   The Return of the King (The Lord of the Rings,...  J.R.R. Tolkien
# 44758  Harry Potter and the Order of the Phoenix (Har...    J.K. Rowling
# 1      Harry Potter and the Order of the Phoenix (Har...    J.K. Rowling
# 44759              Harry Potter and the Sorcerer's Stone    J.K. Rowling
# 2703            Harry Potter and the Philosopher's Stone    J.K. Rowling
# 2      Harry Potter and the Sorcerer's Stone (Harry P...    J.K. Rowling
# ...

# %%
q_books['score'] = q_books.apply(weighted_rating, axis=1)

# %%
q_books = q_books.sort_values('score', ascending=False)
q_books.head(20)
# Out:
#                                                     Name  \
# 41331  Harry Potter and the Deathly Hallows (Harry Po...
# 4      Harry Potter and the Prisoner of Azkaban (Harr...
# 54174  Harry Potter and the Half-Blood Prince (Harry ...
# 40728  Harry Potter and the Half-blood Prince (Harry ...
# 0      Harry Potter and the Half-Blood Prince (Harry ...
# 5      Harry Potter and the Goblet of Fire (Harry Pot...
# 9245   The Return of the King (The Lord of the Rings,...
# 44758  Harry Potter and the Order of the Phoenix (Har...
# 1      Harry Potter and the Order of the Phoenix (Har...
# 44759              Harry Potter and the Sorcerer's Stone
# 2703            Harry Potter and the Philosopher's Stone
# 2      Harry Potter and the Sorcerer's Stone (Harry P...
# 9321   The Lord of the Rings Millennium Edition Boxed...
# 23     The Lord of the Rings (The Lord of the Rings, ...
# 27                         The Lord of the Rings Box Set
# ...

# %%
good_reads.shape
# Out:
# (15988, 18)

# %%
good_reads
# Out:
#           Id                                               Name RatingDist1  \
# 0          1  Harry Potter and the Half-Blood Prince (Harry ...      1:9896
# 1          2  Harry Potter and the Order of the Phoenix (Har...     1:12455
# 2          3  Harry Potter and the Sorcerer's Stone (Harry P...    1:108202
# 3          4  Harry Potter and the Chamber of Secrets (Harry...     1:11896
# 4          5  Harry Potter and the Prisoner of Azkaban (Harr...     1:10128
# ...      ...                                                ...         ...
# 58260  99958  Thomas Paine and the Promise of America (Oxfor...         1:6
# 58262  99962                    Common Sense and Other Writings       1:207
# 58265  99965               Faith of My Fathers: A Family Memoir        1:52
# 58280  99985                  Science Fiction: The Best of 2001         1:1
# 58281  99986                        Nebula Awards Showcase 2001         1:0
#
# ...

# %%
good_reads2[good_reads2['Name'] == 'A Farewell to Arms']
# Out:
# Empty DataFrame
# Columns: [Name, Publisher, Authors, Rating, total_votes]
# Index: []
